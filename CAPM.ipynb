# %%
# Model capital asset pricing model of apple using linear regression to find alpha and beta

# %%
from scipy import stats

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas_datareader as web

# %%
start = pd.to_datetime('2010-01-04')
end = pd.to_datetime('2017-07-18')
spy_etf = web.DataReader('SPY','yahoo',start,end)
aapl = web.DataReader('AAPL','yahoo',start,end)

# %%
aapl['Close'].plot(label='AAPL',figsize=(10,8))
spy_etf['Close'].plot(label='SPY Index')
plt.legend()

# %%
#find cumulative returns for both apple and s&p
aapl['Cumulative'] = aapl['Close']/aapl['Close'].iloc[0]
spy_etf['Cumulative'] = spy_etf['Close']/spy_etf['Close'].iloc[0]

# %%
# graph the 2 cumulative returns for the S&P and apple
aapl['Cumulative'].plot(label='AAPL',figsize=(10,8))
spy_etf['Cumulative'].plot(label='SPY Index')
plt.legend()
plt.title('Cumulative Return')
# Out:
# Text(0.5, 1.0, 'Cumulative Return')

# %%
aapl['Daily Return'] = aapl['Close'].pct_change(1)
spy_etf['Daily Return'] = spy_etf['Close'].pct_change(1)

# %%
# value alpha at 0.3 and create a scatter graph
plt.scatter(aapl['Daily Return'],spy_etf['Daily Return'],alpha=0.3)

# %%
#create histogram of 100 bins for apple's daily return
aapl['Daily Return'].hist(bins=100)

# %%
#create histogram of 100 bins of S&P daily return
spy_etf['Daily Return'].hist(bins=100)

# %%
#use stat lingress library to find alpha,beta for apple
beta,alpha,r_value,p_value,std_err = stats.linregress(aapl['Daily Return'].iloc[1:],spy_etf['Daily Return'].iloc[1:])

# %%
beta
# Out:
# 0.19423150396392763

# %%
alpha
# Out:
# 0.00026461336993233316
